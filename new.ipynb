# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
df = pd.read_csv('bodyPerformance.csv')
df
# Out:
#         age gender  height_cm  weight_kg  body fat_%  diastolic  systolic  \
# 0      27.0      M      172.3      75.24        21.3       80.0     130.0
# 1      25.0      M      165.0      55.80        15.7       77.0     126.0
# 2      31.0      M      179.6      78.00        20.1       92.0     152.0
# 3      32.0      M      174.5      71.10        18.4       76.0     147.0
# 4      28.0      M      173.8      67.70        17.1       70.0     127.0
# ...     ...    ...        ...        ...         ...        ...       ...
# 13388  25.0      M      172.1      71.80        16.2       74.0     141.0
# 13389  21.0      M      179.7      63.90        12.1       74.0     128.0
# 13390  39.0      M      177.2      80.50        20.1       78.0     132.0
# 13391  64.0      F      146.1      57.70        40.4       68.0     121.0
# 13392  34.0      M      164.0      66.10        19.5       82.0     150.0
#
#        gripForce  sit and bend forward_cm  sit-ups counts  broad jump_cm class
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13393 entries, 0 to 13392
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   age                      13393 non-null  float64
#  1   gender                   13393 non-null  object
#  2   height_cm                13393 non-null  float64
#  3   weight_kg                13393 non-null  float64
#  4   body fat_%               13393 non-null  float64
#  5   diastolic                13393 non-null  float64
#  6   systolic                 13393 non-null  float64
#  7   gripForce                13393 non-null  float64
#  8   sit and bend forward_cm  13393 non-null  float64
#  9   sit-ups counts           13393 non-null  float64
#  10  broad jump_cm            13393 non-null  float64
#  11  class                    13393 non-null  object
# dtypes: float64(10), object(2)
# memory usage: 1.2+ MB

# %%
df.duplicated().sum()
# Out:
# 1

# %%
df[df.duplicated()]
# Out:
#         age gender  height_cm  weight_kg  body fat_%  diastolic  systolic  \
# 12473  27.0      F      157.0       49.1        30.7       70.0      86.0
#
#        gripForce  sit and bend forward_cm  sit-ups counts  broad jump_cm class
# 12473       27.7                     19.7            51.0          167.0     A

# %%
df.drop_duplicates()
df
# Out:
#         age gender  height_cm  weight_kg  body fat_%  diastolic  systolic  \
# 0      27.0      M      172.3      75.24        21.3       80.0     130.0
# 1      25.0      M      165.0      55.80        15.7       77.0     126.0
# 2      31.0      M      179.6      78.00        20.1       92.0     152.0
# 3      32.0      M      174.5      71.10        18.4       76.0     147.0
# 4      28.0      M      173.8      67.70        17.1       70.0     127.0
# ...     ...    ...        ...        ...         ...        ...       ...
# 13388  25.0      M      172.1      71.80        16.2       74.0     141.0
# 13389  21.0      M      179.7      63.90        12.1       74.0     128.0
# 13390  39.0      M      177.2      80.50        20.1       78.0     132.0
# 13391  64.0      F      146.1      57.70        40.4       68.0     121.0
# 13392  34.0      M      164.0      66.10        19.5       82.0     150.0
#
#        gripForce  sit and bend forward_cm  sit-ups counts  broad jump_cm class
# ...

# %%
df.duplicated().sum()
# Out:
# 1

# %%
sns.boxplot(data=df)
# Out:
# <Axes: >

# %%
sns.boxplot(x='age',data=df)
# Out:
# <Axes: xlabel='age'>

# %%
sns.boxplot(x='gender',data=df)
# Out:
# <Axes: xlabel='gender'>

# %%
sns.boxplot(x='height_cm',data=df)
# Out:
# <Axes: xlabel='height_cm'>

# %%
sns.boxplot(x='weight_kg',data=df)
# Out:
# <Axes: xlabel='weight_kg'>

# %%
sns.boxplot(x='body fat_%',data=df)
# Out:
# <Axes: xlabel='body fat_%'>

# %%
sns.boxplot(x='diastolic',data=df)
# Out:
# <Axes: xlabel='diastolic'>

# %%
sns.boxplot(x='systolic',data=df)
# Out:
# <Axes: xlabel='systolic'>

# %%
sns.boxplot(x='gripForce',data=df)
# Out:
# <Axes: xlabel='gripForce'>

# %%
sns.boxplot(x='sit and bend forward_cm',data=df)
# Out:
# <Axes: xlabel='sit and bend forward_cm'>

# %%
sns.boxplot(x='sit-ups counts',data=df)
# Out:
# <Axes: xlabel='sit-ups counts'>

# %%
sns.boxplot(x='broad jump_cm',data=df)
# Out:
# <Axes: xlabel='broad jump_cm'>

# %%
sns.boxplot(x='class',data=df)
# Out:
# <Axes: xlabel='class'>

# %%
# Calculate the first quartile (Q1) and third quartile (Q3)
Q1 = df['height_cm'].quantile(0.25)
Q3 = df['height_cm'].quantile(0.75)
IQR = Q3 - Q1

# Calculate the lower and upper bound for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Filter the dataset to remove outliers
df = df[(df['height_cm'] >= lower_bound) & (df['height_cm'] <= upper_bound)]

# Display the filtered dataset
df.info(), df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13383 entries, 0 to 13392
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   age                      13383 non-null  float64
#  1   gender                   13383 non-null  object
#  2   height_cm                13383 non-null  float64
#  3   weight_kg                13383 non-null  float64
#  4   body fat_%               13383 non-null  float64
#  5   diastolic                13383 non-null  float64
#  6   systolic                 13383 non-null  float64
#  7   gripForce                13383 non-null  float64
#  8   sit and bend forward_cm  13383 non-null  float64
#  9   sit-ups counts           13383 non-null  float64
#  10  broad jump_cm            13383 non-null  float64
#  11  class                    13383 non-null  object
# dtypes: float64(10), object(2)
# memory usage: 1.3+ MB
# (None,
# ...

# %%
# Calculate the first quartile (Q1) and third quartile (Q3)
Q1 = df['weight_kg'].quantile(0.25)
Q3 = df['weight_kg'].quantile(0.75)
IQR = Q3 - Q1

# Calculate the lower and upper bound for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Filter the dataset to remove outliers
df = df[(df['weight_kg'] >= lower_bound) & (df['weight_kg'] <= upper_bound)]

# Display the filtered dataset
df.info(), df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13300 entries, 0 to 13392
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   age                      13300 non-null  float64
#  1   gender                   13300 non-null  object
#  2   height_cm                13300 non-null  float64
#  3   weight_kg                13300 non-null  float64
#  4   body fat_%               13300 non-null  float64
#  5   diastolic                13300 non-null  float64
#  6   systolic                 13300 non-null  float64
#  7   gripForce                13300 non-null  float64
#  8   sit and bend forward_cm  13300 non-null  float64
#  9   sit-ups counts           13300 non-null  float64
#  10  broad jump_cm            13300 non-null  float64
#  11  class                    13300 non-null  object
# dtypes: float64(10), object(2)
# memory usage: 1.3+ MB
# (None,
# ...

# %%
# Calculate the first quartile (Q1) and third quartile (Q3)
Q1 = df['body fat_%'].quantile(0.25)
Q3 = df['body fat_%'].quantile(0.75)
IQR = Q3 - Q1

# Calculate the lower and upper bound for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Filter the dataset to remove outliers
df = df[(df['body fat_%'] >= lower_bound) & (df['body fat_%'] <= upper_bound)]

# Display the filtered dataset
df.info(), df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13218 entries, 0 to 13392
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   age                      13218 non-null  float64
#  1   gender                   13218 non-null  object
#  2   height_cm                13218 non-null  float64
#  3   weight_kg                13218 non-null  float64
#  4   body fat_%               13218 non-null  float64
#  5   diastolic                13218 non-null  float64
#  6   systolic                 13218 non-null  float64
#  7   gripForce                13218 non-null  float64
#  8   sit and bend forward_cm  13218 non-null  float64
#  9   sit-ups counts           13218 non-null  float64
#  10  broad jump_cm            13218 non-null  float64
#  11  class                    13218 non-null  object
# dtypes: float64(10), object(2)
# memory usage: 1.3+ MB
# (None,
# ...

# %%
# Calculate the first quartile (Q1) and third quartile (Q3)
Q1 = df['diastolic'].quantile(0.25)
Q3 = df['diastolic'].quantile(0.75)
IQR = Q3 - Q1

# Calculate the lower and upper bound for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Filter the dataset to remove outliers
df = df[(df['diastolic'] >= lower_bound) & (df['diastolic'] <= upper_bound)]

# Display the filtered dataset
df.info(), df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13164 entries, 0 to 13392
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   age                      13164 non-null  float64
#  1   gender                   13164 non-null  object
#  2   height_cm                13164 non-null  float64
#  3   weight_kg                13164 non-null  float64
#  4   body fat_%               13164 non-null  float64
#  5   diastolic                13164 non-null  float64
#  6   systolic                 13164 non-null  float64
#  7   gripForce                13164 non-null  float64
#  8   sit and bend forward_cm  13164 non-null  float64
#  9   sit-ups counts           13164 non-null  float64
#  10  broad jump_cm            13164 non-null  float64
#  11  class                    13164 non-null  object
# dtypes: float64(10), object(2)
# memory usage: 1.3+ MB
# (None,
# ...

# %%
# Calculate the first quartile (Q1) and third quartile (Q3)
Q1 = df['systolic'].quantile(0.25)
Q3 = df['systolic'].quantile(0.75)
IQR = Q3 - Q1

# Calculate the lower and upper bound for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Filter the dataset to remove outliers
df = df[(df['systolic'] >= lower_bound) & (df['systolic'] <= upper_bound)]

# Display the filtered dataset
df.info(), df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13145 entries, 0 to 13392
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   age                      13145 non-null  float64
#  1   gender                   13145 non-null  object
#  2   height_cm                13145 non-null  float64
#  3   weight_kg                13145 non-null  float64
#  4   body fat_%               13145 non-null  float64
#  5   diastolic                13145 non-null  float64
#  6   systolic                 13145 non-null  float64
#  7   gripForce                13145 non-null  float64
#  8   sit and bend forward_cm  13145 non-null  float64
#  9   sit-ups counts           13145 non-null  float64
#  10  broad jump_cm            13145 non-null  float64
#  11  class                    13145 non-null  object
# dtypes: float64(10), object(2)
# memory usage: 1.3+ MB
# (None,
# ...

# %%
# Calculate the first quartile (Q1) and third quartile (Q3)
Q1 = df['sit and bend forward_cm'].quantile(0.25)
Q3 = df['sit and bend forward_cm'].quantile(0.75)
IQR = Q3 - Q1

# Calculate the lower and upper bound for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Filter the dataset to remove outliers
df = df[(df['sit and bend forward_cm'] >= lower_bound) & (df['sit and bend forward_cm'] <= upper_bound)]

# Display the filtered dataset
df.info(), df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12755 entries, 0 to 13392
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   age                      12755 non-null  float64
#  1   gender                   12755 non-null  object
#  2   height_cm                12755 non-null  float64
#  3   weight_kg                12755 non-null  float64
#  4   body fat_%               12755 non-null  float64
#  5   diastolic                12755 non-null  float64
#  6   systolic                 12755 non-null  float64
#  7   gripForce                12755 non-null  float64
#  8   sit and bend forward_cm  12755 non-null  float64
#  9   sit-ups counts           12755 non-null  float64
#  10  broad jump_cm            12755 non-null  float64
#  11  class                    12755 non-null  object
# dtypes: float64(10), object(2)
# memory usage: 1.3+ MB
# (None,
# ...

# %%
# Calculate the first quartile (Q1) and third quartile (Q3)
Q1 = df['broad jump_cm'].quantile(0.25)
Q3 = df['broad jump_cm'].quantile(0.75)
IQR = Q3 - Q1

# Calculate the lower and upper bound for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Filter the dataset to remove outliers
df = df[(df['broad jump_cm'] >= lower_bound) & (df['broad jump_cm'] <= upper_bound)]

# Display the filtered dataset
df.info(), df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12718 entries, 0 to 13392
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   age                      12718 non-null  float64
#  1   gender                   12718 non-null  object
#  2   height_cm                12718 non-null  float64
#  3   weight_kg                12718 non-null  float64
#  4   body fat_%               12718 non-null  float64
#  5   diastolic                12718 non-null  float64
#  6   systolic                 12718 non-null  float64
#  7   gripForce                12718 non-null  float64
#  8   sit and bend forward_cm  12718 non-null  float64
#  9   sit-ups counts           12718 non-null  float64
#  10  broad jump_cm            12718 non-null  float64
#  11  class                    12718 non-null  object
# dtypes: float64(10), object(2)
# memory usage: 1.3+ MB
# (None,
# ...

# %%
df.reset_index(drop=True, inplace=True)
df
# Out:
#         age gender  height_cm  weight_kg  body fat_%  diastolic  systolic  \
# 0      27.0      M      172.3      75.24        21.3       80.0     130.0
# 1      25.0      M      165.0      55.80        15.7       77.0     126.0
# 2      31.0      M      179.6      78.00        20.1       92.0     152.0
# 3      32.0      M      174.5      71.10        18.4       76.0     147.0
# 4      28.0      M      173.8      67.70        17.1       70.0     127.0
# ...     ...    ...        ...        ...         ...        ...       ...
# 12713  25.0      M      172.1      71.80        16.2       74.0     141.0
# 12714  21.0      M      179.7      63.90        12.1       74.0     128.0
# 12715  39.0      M      177.2      80.50        20.1       78.0     132.0
# 12716  64.0      F      146.1      57.70        40.4       68.0     121.0
# 12717  34.0      M      164.0      66.10        19.5       82.0     150.0
#
#        gripForce  sit and bend forward_cm  sit-ups counts  broad jump_cm class
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# age                        0
# gender                     0
# height_cm                  0
# weight_kg                  0
# body fat_%                 0
# diastolic                  0
# systolic                   0
# gripForce                  0
# sit and bend forward_cm    0
# sit-ups counts             0
# broad jump_cm              0
# class                      0
# dtype: int64

# %%
df['gender'].value_counts()
# Out:
# gender
# M    8001
# F    4717
# Name: count, dtype: int64

# %%
df['class'].value_counts()
# Out:
# class
# C    3324
# A    3318
# B    3315
# D    2761
# Name: count, dtype: int64

# %%
df['gender']=df['gender'].map({'M':0, 'F':1})
df['class']=df['class'].map({'A':0, 'B':1, 'C':2,'D':3})
df
# Out:
#         age  gender  height_cm  weight_kg  body fat_%  diastolic  systolic  \
# 0      27.0       0      172.3      75.24        21.3       80.0     130.0
# 1      25.0       0      165.0      55.80        15.7       77.0     126.0
# 2      31.0       0      179.6      78.00        20.1       92.0     152.0
# 3      32.0       0      174.5      71.10        18.4       76.0     147.0
# 4      28.0       0      173.8      67.70        17.1       70.0     127.0
# ...     ...     ...        ...        ...         ...        ...       ...
# 12713  25.0       0      172.1      71.80        16.2       74.0     141.0
# 12714  21.0       0      179.7      63.90        12.1       74.0     128.0
# 12715  39.0       0      177.2      80.50        20.1       78.0     132.0
# 12716  64.0       1      146.1      57.70        40.4       68.0     121.0
# 12717  34.0       0      164.0      66.10        19.5       82.0     150.0
#
# ...

# %%
X = df.iloc[:,0:11]
Y = df.iloc[:,11]
print(X)
print(Y)
# Out:
#         age  gender  height_cm  weight_kg  body fat_%  diastolic  systolic  \
# 0      27.0       0      172.3      75.24        21.3       80.0     130.0
# 1      25.0       0      165.0      55.80        15.7       77.0     126.0
# 2      31.0       0      179.6      78.00        20.1       92.0     152.0
# 3      32.0       0      174.5      71.10        18.4       76.0     147.0
# 4      28.0       0      173.8      67.70        17.1       70.0     127.0
# ...     ...     ...        ...        ...         ...        ...       ...
# 12713  25.0       0      172.1      71.80        16.2       74.0     141.0
# 12714  21.0       0      179.7      63.90        12.1       74.0     128.0
# 12715  39.0       0      177.2      80.50        20.1       78.0     132.0
# 12716  64.0       1      146.1      57.70        40.4       68.0     121.0
# 12717  34.0       0      164.0      66.10        19.5       82.0     150.0
#
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size = 0.25, random_state= 42)

from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)

X_test=scaler.transform(X_test)
X_test

from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(n_jobs = -1)

classifier.fit(X_train,Y_train)

#Predicting values
Y_pred = classifier.predict(X_test)

from sklearn.metrics import accuracy_score
score = accuracy_score(Y_test,Y_pred)
print(score)
# Out:
# 0.6003144654088051

# %%
X_train
# Out:
# array([[-0.56533228,  1.31137464, -0.87748705, ...,  1.30110349,
#         -0.38531761,  0.75910173],
#        [ 0.69171454, -0.76255859,  0.28239224, ..., -0.67474981,
#         -1.03071146, -0.19796863],
#        [ 0.02621916, -0.76255859,  0.30655639, ..., -1.33336757,
#         -0.17018633,  0.99190263],
#        ...,
#        [-1.0829398 , -0.76255859,  1.53892813, ..., -0.38839426,
#          0.76204922,  1.66443855],
#        [ 0.02621916,  1.31137464, -0.26130118, ...,  0.82861683,
#         -0.24189676, -0.56010336],
#        [-0.63927621, -0.76255859, -0.09215211, ...,  0.72839239,
#          1.19231179,  1.12123646]])

# %%
X_test
# Out:
# array([[-1.00899587, -0.76255859,  0.00450449, ..., -0.58884314,
#          0.47520751, -1.51717372],
#        [ 0.32199488, -0.76255859,  1.17646585, ..., -1.0613298 ,
#          0.11665538,  0.81083526],
#        [-0.78716407,  1.31137464,  0.28239224, ...,  0.82861683,
#         -0.95900103, -0.71530396],
#        ...,
#        [-0.1216687 ,  1.31137464, -1.09496441, ...,  0.04113907,
#         -1.10242189, -0.79290426],
#        [-1.0829398 ,  1.31137464, -1.21578517, ...,  0.82861683,
#         -0.45702804, -0.50836983],
#        [ 0.98749026,  1.31137464, -1.22786725, ...,  0.38476573,
#         -1.67610531, -1.43957342]])

# %%
Y_train
# Out:
# 3265     0
# 8660     3
# 10078    2
# 7202     1
# 12601    0
#         ..
# 11964    3
# 5191     1
# 5390     1
# 860      0
# 7270     0
# Name: class, Length: 9538, dtype: int64

# %%
Y_test
# Out:
# 6237     2
# 1825     2
# 3646     1
# 12326    1
# 11362    2
#         ..
# 2260     0
# 1775     3
# 3344     2
# 3669     1
# 93       2
# Name: class, Length: 3180, dtype: int64

# %%
from sklearn.tree import DecisionTreeClassifier
treemodel = DecisionTreeClassifier(max_depth=2)
treemodel
treemodel.fit(X_train,Y_train)
import matplotlib.pyplot as plt
from sklearn import tree

plt.figure(figsize = (15,10))

tree.plot_tree(treemodel,filled = True)
treemodel = DecisionTreeClassifier()
treemodel...
treemodel.fit(X_train,Y_train)
from sklearn import tree

plt.figure(figsize =(15,10))
tree.plot_tree(treemodel,filled = True)
Y_pred=treemodel.predict(X_test)
Y_pred
from sklearn.metrics import accuracy_score,classification_report
score=accuracy_score(Y_pred,Y_test)
print(score)
# Out:
# 0.6289308176100629

# %%
from sklearn.ensemble import RandomForestClassifier
fit_rf=RandomForestClassifier(random_state=40)
fit_rf.fit(X_train,Y_train)
fit_rf.predict(X_test)
accuracy_rf=fit_rf.score(X_test,Y_test)
accuracy_rf
# Out:
# 0.7154088050314465

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()

#fitting-
gnb.fit(X_train, Y_train)
#predicting
y_pred=gnb.predict(X_test)

# %%
# calculating score:
#importing libraries
from sklearn.metrics import accuracy_score,classification_report,precision_score,recall_score,f1_score

#scores
acc_score_gnb = accuracy_score(Y_pred,Y_test)
recall_scr_gnb = recall_score(Y_test, Y_pred, average='macro')
precision_scr_gnb = precision_score(Y_test, Y_pred, average='macro')
f1_scr_gnb = f1_score(Y_test, Y_pred, average='macro')
class_report = classification_report(Y_pred,Y_test)
print('Accuracy score is:\n',acc_score_gnb,'\n')
print(f"Recall: {recall_scr_gnb}")
print(f"Precision: {precision_scr_gnb}")
print(f"F1 Score: {f1_scr_gnb}")
print('Classification report is:\n',class_report)
# Out:
# Accuracy score is:
#  0.6289308176100629
#
# Recall: 0.6339040196433603
# Precision: 0.6332106744908748
# F1 Score: 0.6334526756902774
# Classification report is:
#                precision    recall  f1-score   support
#
#            0       0.68      0.67      0.68       845
#            1       0.53      0.52      0.52       836
#            2       0.58      0.61      0.59       807
#            3       0.75      0.74      0.74       692
#
#     accuracy                           0.63      3180
#    macro avg       0.63      0.63      0.63      3180
# weighted avg       0.63      0.63      0.63      3180

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=4)
knn.fit(X_train,Y_train)
Y_prediction=knn.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(Y_test,Y_prediction)
# Out:
# array([[704, 108,  23,   1],
#        [327, 351, 120,  20],
#        [117, 329, 353,  45],
#        [ 27,  89, 189, 377]], dtype=int64)

# %%
score = accuracy_score(Y_test, Y_prediction, normalize=True)
print(score)
# Out:
# 0.5613207547169812

# %%
a=pd.DataFrame({'Algorithms':['Logistic Regression','Decision Tree Classifier','Random Classifier','KNearest Algorithm','Naive Bayes'],
               'Accuracy':[0.6003144654088051,0.6355345911949686,0.7154088050314465,0.5613207547169812,0.6355345911949686]},
                index=[1,2,3,4,5],
              columns=['Algorithms','Accuracy'])
(a)
# Out:
#                  Algorithms  Accuracy
# 1       Logistic Regression  0.600314
# 2  Decision Tree Classifier  0.635535
# 3         Random Classifier  0.715409
# 4        KNearest Algorithm  0.561321
# 5               Naive Bayes  0.635535

# %%
df.count()
# Out:
# age                        12718
# gender                     12718
# height_cm                  12718
# weight_kg                  12718
# body fat_%                 12718
# diastolic                  12718
# systolic                   12718
# gripForce                  12718
# sit and bend forward_cm    12718
# sit-ups counts             12718
# broad jump_cm              12718
# class                      12718
# dtype: int64

# %%
df.mean()
# Out:
# age                         36.674320
# gender                       0.370892
# height_cm                  168.517652
# weight_kg                   67.011818
# body fat_%                  22.938988
# diastolic                   78.783747
# systolic                   130.186350
# gripForce                   37.059557
# sit and bend forward_cm     15.989571
# sit-ups counts              40.338135
# broad jump_cm              191.433645
# class                        1.434660
# dtype: float64

# %%
df.median()
# Out:
# age                         32.0
# gender                       0.0
# height_cm                  169.1
# weight_kg                   67.2
# body fat_%                  22.6
# diastolic                   79.0
# systolic                   130.0
# gripForce                   38.0
# sit and bend forward_cm     16.5
# sit-ups counts              42.0
# broad jump_cm              194.0
# class                        1.0
# dtype: float64

# %%
df.mode()
# Out:
#     age  gender  height_cm  weight_kg  body fat_%  diastolic  systolic  \
# 0  21.0       0      170.0       70.5        23.1       80.0     120.0
#
#    gripForce  sit and bend forward_cm  sit-ups counts  broad jump_cm  class
# 0       43.1                     20.0            45.0          211.0      2

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score


# Split the data into training and testing sets
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.25, random_state=42)

# Standardize features
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Train a Support Vector Classifier
clf = SVC(kernel='linear')
clf.fit(X_train, Y_train)

# Make predictions
Y_pred = clf.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(Y_test, Y_pred)
print(f"Accuracy: {accuracy:.2f}")
# Out:
# Accuracy: 0.61

# %%
a=pd.DataFrame({'Algorithms':['Logistic Regression','Decision Tree Classifier','Random Classifier','KNearest Algorithm','Naive Bayes','Support Vector Classifier'],
               'Accuracy':[0.6003144654088051,0.6355345911949686,0.7154088050314465,0.5613207547169812,0.6355345911949686,0.61]},
                index=[1,2,3,4,5,6],
              columns=['Algorithms','Accuracy'])
(a)
# Out:
#                   Algorithms  Accuracy
# 1        Logistic Regression  0.600314
# 2   Decision Tree Classifier  0.635535
# 3          Random Classifier  0.715409
# 4         KNearest Algorithm  0.561321
# 5                Naive Bayes  0.635535
# 6  Support Vector Classifier  0.610000

# %%
a = X.sample(3)
mc_user_y_pred1 = classifier_regressor.predict(a)
dtc_user_y_pred1 =  treemodel.predict(a)
rfc_user_y_pred1 = clf.predict(a)
knn_user_y_pred1 = gnb.predict(a)
nvb_user_y_pred1 = knn.predict(a)
SVC_user_y_pred1 = clf.predict(a)
print(a)
print("Prediction : ",mc_user_y_pred1)
print("Prediction : ",dtc_user_y_pred1)
print("Prediction : ",knn_user_y_pred1)
print("Prediction : ",rfc_user_y_pred1)
print("Prediction : ",nvb_user_y_pred1)
print("Prediction : ",SVC_user_y_pred1)
